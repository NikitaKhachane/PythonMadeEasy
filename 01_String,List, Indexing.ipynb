# %%
s= 'niki'
s
# Out:
# 'niki'

# %%
s[1]
# Out:
# 'i'

# %%
type(s)
# Out:
# str

# %%
print(s[0])
# Out:
# n

# %%
s[3]
# Out:
# 'i'

# %%
s[-1]
# Out:
# 'i'

# %%
s[-4]
# Out:
# 'n'

# %%
s[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-a81280e08423> in <cell line: 1>()
# ----> 1 s[4]
#
# IndexError: string index out of range

# %%
a = "My nam is nikitA"

# %%
a[0]
# Out:
# 'M'

# %%
a[-1]
# Out:
# 'A'

# %%
a[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-cd7724b6c85f> in <cell line: 1>()
# ----> 1 a[100]
#
# IndexError: string index out of range

# %%
a[M:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5d95381d09db> in <cell line: 1>()
# ----> 1 a[M:]
#
# NameError: name 'M' is not defined

# %%
a[0:6]
# Out:
# 'My nam'

# %%
a[0:12]
# Out:
# 'My nam is ni'

# %%
a[0:12:1]
# Out:
# 'My nam is ni'

# %%
a[0:12:2]
# Out:
# 'M a sn'

# %%
b='abcdefghijklmnopqr'

# %%
b[0:12:]
# Out:
# 'abcdefghijkl'

# %%
b[0:12:1]
# jump size which is by default 1 that is 0+1 = 1 1+1 =2
# Out:
# 'abcdefghijkl'

# %%
b[0:12:2]
# jump size 2 i.e. 0+2=2 => c
# Out:
# 'acegik'

# %%
b[0:200]
# Out:
# 'abcdefghijklmnopqr'

# %%
b[0::3]
# Out:
# 'adgjmp'

# %%
b[0:100:-1]
# empty string => the traversal and the jump diirection arare opposite to each other
# Out:
# ''

# %%
b[100:0:-1]
# the traversal and jump has same direction
# we dont get a coz the brackets are exclusive
# Out:
# 'rqponmlkjihgfedcb'

# %%
b[-1:-4]
# Out:
# ''

# %%
b[-5:-1]
# Out:
# 'nopq'

# %%
b[0:-1]
# Out:
# 'abcdefghijklmnopq'

# %%
b[-1:-6:-1]
# Out:
# 'rqpon'

# %%
b[-1:-6]
# it is empty coz jump iis by default +1
# Out:
# ''

# %%
b[-1:-6:-2]
# Out:
# 'rpn'

# %%
s = '_nikita_'
s[-1:-8:-1]
# Out:
# '_atikin'

# %%
s[-1:-8:-2]
# Out:
# '_tkn'

# %%
s[::]
# Out:
# '_nikita_'

# %%
s[::-1]
# Out:
# '_atikin_'

# %%
s[-1::-1]
# Out:
# '_atikin_'

# %%
s[-3:]
# Out:
# 'ta_'

# %%
s[-3:-1]
# Out:
# 'ta'

# %%
b
# Out:
# 'abcdefghijklmnopqr'

# %%
b[-5:5]
# Out:
# ''

# %%
b[-5:5:-1]
# Out:
# 'nmlkjihg'

# %%
"ssudh"*4
# Out:
# 'ssudhssudhssudhssudh'

# %%
"suddh " +"kkumar"
# Out:
# 'suddh kkumar'

# %%
len(s)
# Out:
# 8

# %%
"sudh"*3
# Out:
# 'sudhsudhsudh'

# %%
s
# Out:
# '_nikita_'

# %%
s.find("i")
# Out:
# 2

# %%
s.find('a')
# Out:
# 6

# %%
s.find("fg")
# if not avilable it returns -1
# Out:
# -1

# %%
s.count("i")
# Out:
# 2

# %%
s.count("n")
# Out:
# 1

# %%
s.count("x")
# Out:
# 0

# %%
a = "my name is nikita"

# %%
a.split()
# Out:
# ['my', 'name', 'is', 'nikita']

# %%
a.split('a')
# Out:
# ['my n', 'me is nikit', '']

# %%
l = a.split()
l
# Out:
# ['my', 'name', 'is', 'nikita']

# %%
l[0]
# Out:
# 'my'

# %%
l[2]
# Out:
# 'is'

# %%
l[0:3]
# Out:
# ['my', 'name', 'is']

# %%
l[0:3:2]
# Out:
# ['my', 'is']

# %%
a
# Out:
# 'my name is nikita'

# %%
a.upper()
# Out:
# 'MY NAME IS NIKITA'

# %%
a.capitalize()
# Out:
# 'My name is nikita'

# %%
a.swapcase()
# Out:
# 'MY NAME IS NIKITA'

# %%
a.title()
# Out:
# 'My Name Is Nikita'

# %%
b = "nikita "
c = "kumar"
d = '1234_'

# %%
b.join(c)
# Out:
# 'knikita unikita mnikita anikita r'

# %%
d.join(b)
# Out:
# 'n1234_i1234_k1234_i1234_t1234_a1234_ '

# %%
' '.join(c)
# Out:
# 'k u m a r'

# %%
for i in reversed(b):
  print(i)
# Out:
#
# a
# t
# i
# k
# i
# n

# %%
b[::-1]
# Out:
# ' atikin'

# %%
c = " kumar "

# %%
c.rstrip()
# Out:
# ' kumar'

# %%
c.lstrip()
# Out:
# 'kumar '

# %%
c.strip()
# Out:
# 'kumar'

# %%
b
# Out:
# 'nikita '

# %%
b.replace("i","X")
# Out:
# 'nXkXta '

# %%
"nikita\tsid".expandtabs()
# Out:
# 'nikita  sid'

# %%
s= "sudh"
s.center(40,'+')
# Out:
# '++++++++++++++++++sudh++++++++++++++++++'

# %%
s = "sudh"

# %%
s.isalnum()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %%
s1="SUD"
s1.islower()
# Out:
# False

# %%
s.isalpha()
# Out:
# True

# %%
s.isdigit
# Out:
# <function str.isdigit()>

# %%
s.isnumeric()
# Out:
# False

# %%
s = "    "
s.isspace()
# Out:
# True

# %%
s1.isspace()
# Out:
# False

# %%
s="4342"

# %%
s.isdigit()
# Out:
# True

# %%
s.isdecimal()
# Out:
# True

# %%
s = "sudh"

# %%
s.endswith("h")
# Out:
# True

# %%
s.endswith("n")
# Out:
# False

# %%
s.startswith("s")
# Out:
# True

# %%
s.istitle()
# Out:
# False

# %% [markdown]
# **LIST**

# %%
# list is collection is a collection of heterogeneous or homogenieous data

# %%
l = ['nik' , 4 , 6.4 , 8+2j, True, [3,4,5]]

# %%
type(l)
# Out:
# list

# %%
type(l[0])
# Out:
# str

# %%
type(l[4])
# Out:
# bool

# %%
type(l[2])
# Out:
# float

# %%
l
# Out:
# ['nik', 4, 6.4, (8+2j), True, [3, 4, 5]]

# %%
l[-1]
# Out:
# [3, 4, 5]

# %%
l[-3]
# Out:
# (8+2j)

# %%
l[::-1]
# Out:
# [[3, 4, 5], True, (8+2j), 6.4, 4, 'nik']

# %%
l[-1:-3]
# Out:
# []

# %%
l[-1:-3:-1]
# Out:
# [[3, 4, 5], True]

# %%
l[-1:6]
# Out:
# [[3, 4, 5]]

# %%
l[-1:6:-1]
# Out:
# []

# %%
l
# Out:
# ['nik', 4, 6.4, (8+2j), True, [3, 4, 5]]

# %%
l[0][1]
# Out:
# 'i'

# %%
l[3]
# Out:
# (8+2j)

# %%
l[3].real
# Out:
# 8.0

# %%
l[3].imag
# Out:
# 2.0

# %%
l1 = ["sudh", "kumar", 2443]
l2 = ['xyz', 'pqr' , 233.244]

# %%
l1 + l2
# Out:
# ['sudh', 'kumar', 2443, 'xyz', 'pqr', 233.244]

# %%
l1 + 'nik'
# different datatype
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-e2e1853c2101> in <cell line: 1>()
# ----> 1 l1 + 'nik'
#       2 # different datatype
#
# TypeError: can only concatenate list (not "str") to list

# %%
l1 + ['nik']
# Out:
# ['sudh', 'kumar', 2443, 'nik']

# %%
l2.append('emir')

# %%
l1
# Out:
# ['sudh', 'kumar', 2443]

# %%
l1*2
# Out:
# ['sudh', 'kumar', 2443, 'sudh', 'kumar', 2443]

# %%
l1
# Out:
# ['sudh', 'kumar', 2443]

# %%
l1[0] = 'emir'
l1
# Out:
# ['emir', 'kumar', 2443]

# %%
l1
# Out:
# ['emir', 'kumar', 2443]

# %%
l1[1]
# Out:
# 'kumar'

# %%
l1[1][0]
# Out:
# 'k'

# %%
l1[1][0] = 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-213-5bec5324ae7a> in <cell line: 1>()
# ----> 1 l1[1][0] = 's'
#
# TypeError: 'str' object does not support item assignment

# %%
s= "sudh"
s
# Out:
# 'sudh'

# %%
s.replace('s','Z')
# Out:
# 'Zudh'

# %%
l1
# Out:
# ['emir', 'kumar', 2443]

# %%
'emir' in l1
# Out:
# True

# %%
'sudh' in l1
# Out:
# False

# %%
l2
# Out:
# ['xyz', 'pqr', 233.244, 'emir']

# %%
l2.append('emirD')

# %%
l2
# Out:
# ['xyz', 'pqr', 233.244, 'emir', 'emirD']

# %%
l2.pop()
# Out:
# 'emirD'

# %%
l2.pop(1)
# Out:
# 'pqr'

# %%
l2
# Out:
# ['xyz', 233.244, 'emir']

# %%
l2.insert(1,'gre')

# %%
l2.insert(-1,[1,2,3])
l2
# Out:
# ['xyz', 'gre', 233.244, [1, 2, 3], 'emir']

# %%
l2 = ['xyz', 233.244, 'emir']

# %%
l2.insert(-1,[1,2,3])
l2
# Out:
# ['xyz', 233.244, [1, 2, 3], 'emir']

# %%
l2.insert(1,'gre')

# %%
l2
# Out:
# ['xyz', 'gre', 233.244, [1, 2, 3], 'emir']

# %%
l2[3][1]
# Out:
# 2

# %%
l2.count('gre')
# Out:
# 1

# %%
l2.count('hgfds')
# Out:
# 0

# %%
l2
# Out:
# ['xyz', 'gre', 233.244, [1, 2, 3], 'emir']

# %%
l2.append([3,3,3,33])
l2
# Out:
# ['xyz', 'gre', 233.244, [1, 2, 3], 'emir', [3, 3, 3, 33]]

# %%
l2.extend([2,2,2])
l2
# Out:
# ['xyz', 'gre', 233.244, [1, 2, 3], 'emir', [3, 3, 3, 33], 2, 2, 2]

# %%
l3 = [1 , 'nik' , 3.3]

# %%
l3.append('rrr')
l3
# Out:
# [1, 'nik', 3.3, 'rrr']

# %%
l3.extend('ppp')
l3
# Out:
# [1, 'nik', 3.3, 'rrr', 'p', 'p', 'p']
