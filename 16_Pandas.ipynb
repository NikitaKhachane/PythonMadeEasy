# %%
# pandas calss 3

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# alwaysv understand the meaning of each and every feature and what does it stand for

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# if htere are less number of records
# that mans there are nul records

# %%
df.describe()   # stats
# it gives you count
# avg\
# std dev
# min max and percentiles
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# not all numbes in above coulmnn have meaning though

# for example
# mean(Fare) means that is the avg ticking fare
# But
# mean(PasssengerId) = that is just avg of id numbers for each passenger\
# mean(age) = means something
# and does not mean anything. (its just id, it could be anythihng)

 # this is why it is so imp to understand all the attributes

# %%
 # std dev : disperssion of data from the mean/avg
 # bellcurve

 # sigma = sqrt(((x-mena)**2)/N)

# %%
# we will also talk abt pandas profiling
# it gives us in depth stats

# %%
# df.describe()  onlt gives stat for numerical/qunatative data clumns

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# filter out object columns
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
# filtering out the numeric data

df.dtypes[df.dtypes == "object"]
# condion inside a lsit
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
# Area of intrest the object columns
# thus

col_names = df.dtypes[df.dtypes == "object"].index
col_names
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(df.dtypes[df.dtypes == "object"].index)
# Out:
# pandas.core.indexes.base.Index

# %%
df[col_names]

# we finally hv a df with only catagorical values
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_names].describe()
# and thst how we get stats for catagirical data
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# adding a new column

df["ineuron"] = "sudh"

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# extracting column from dataframe
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Name"][0:15]
# only specific number of records
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
# alternate records
df["Name"][0:30:2]  # list slicing
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 16                                 Rice, Master. Eugene
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                                 Fynney, Mr. Joseph J
# 22                          McGowan, Miss. Anna "Annie"
# 24                        Palsson, Miss. Torborg Danira
# 26                              Emir, Mr. Farred Chehab
# 28                        O'Dwyer, Miss. Ellen "Nellie"
# Name: Name, dtype: object

# %%
# we hv some null values innfew clumns
# Cabin and Age

# %%
# columns wit hnull values  on what indexes

df["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df["Age"].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df["Age"].isnull() == True]
# syntaf
# df[condition]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df["Age"].isnull() == True].index
# only the 8index number
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
# how many placec do we hv a null value
# how n=many null values are there?

len(df[df["Age"].isnull() == True].index)
# Out:
# 177

# %%
# to showcase a comple record of the null vlaue

ind = df[df["Age"].isnull() == True].index
ind
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
# to showcase a comple record of the null vlaue

ind = df[df["Age"].isnull() == True].index

df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# OR we can do this

df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Notice4 that

# df[df['Age'].isnull()] and
# df.loc[ind]     are giving exact same output

# %%
# person naem wit hhaighest paid fare in df

max(df["Fare"])
# Out:
# 512.3292

# %%
df[df['Fare'] == max(df["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258    sudh
# 679    sudh
# 737    sudh

# %%
df[df['Fare'] == max(df["Fare"])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df[df['Fare'] == max(df["Fare"])]["Name"].head()
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# Q.1} Find out how many male and female passengers were onboarded
#

# %%
male = df[df['Sex'] == 'male']['Sex'].count()
male
# Out:
# 577

# %%
fm = df[df["Sex"] == "female"]['Sex'].count()
fm
# Out:
# 314

# %%
# Q.2} How many survived we have

# %%
df[df['Survived'] == 1]['Survived'].count()
# Out:
# 342

# %%
# Q.3} how many casulities we have

# How may did not survive

df[df['Survived'] == 0]['Survived'].count()
# Out:
# 549

# %%
# to cross check total no. of records

df[df['Survived'] == 1]['Survived'].count()  + df[df['Survived'] == 0]['Survived'].count()
# Out:
# 891

# %%
# Q.4} what is name of eldest person|

# %%
df[df['Age'] == max(df["Age"])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[df['Age'] == max(df["Age"])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked ineuron
# 630  male  80.0      0      0  27042  30.0   A23        S    sudh

# %%
# for example

df[df['PassengerId'] == 259]
# Out:
#      PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 258          259         1       1  Ward, Miss. Anna  female  35.0      0
#
#      Parch    Ticket      Fare Cabin Embarked ineuron
# 258      0  PC 17755  512.3292   NaN        C    sudh

# %%
# Q.5} how many passengers do we hv in 1st , 2nd , third class

# %%
# passengers in 1st class
df[df['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Number of passengers in 1st class

df[df['Pclass'] == 1].count()['Pclass']
# Out:
# 216

# %%
# Number of passenfgeres in 2nd class

df[df['Pclass'] == 2].count()['Pclass']
# Out:
# 184

# %%
# Number of passengers in 3rd class

df[df['Pclass'] == 3].count()['Pclass']
# Out:
# 491

# %%
# Q.6}passengers who's name start with "s"

# %%
df[df['Name'].str.startswith('S')].count()["Name"]
# Out:
# 86

# %%
# Q.7} try to create a new column which is summerization of "SibSp" and "parch"

# %%
# SibSp : Sibling Spose
# Parch : Parent Child/ children

# %%
df['fam'] = df['SibSp'] + df['Parch']

df[['fam','SibSp','Parch']]
# this will give us the total family members the person onboard with in the ship
# Out:
#      fam  SibSp  Parch
# 0      1      1      0
# 1      1      1      0
# 2      0      0      0
# 3      1      1      0
# 4      0      0      0
# ..   ...    ...    ...
# 886    0      0      0
# 887    0      0      0
# 888    3      1      2
# 889    0      0      0
# 890    0      0      0
#
# [891 rows x 3 columns]

# %%
# Q.8} How mnay people in age group under 25

# %%
df[df['Age'] <= 25].count()["Age"]
# Out:
# 301

# %%
# Q.9} how many people died in age group les than 40

# %%
temp1 = df[df['Age'] <= 40]
temp2 = df[df['Survived'] == 0]

pd.merge(temp1, temp2, on=['PassengerId', 'Name']).count()['Name']
# mearge 2 pdf on the unique columns and take common records
# '''as we are mearging on common names and id onlyu the
#  common record will be present in new df'''
# Out:
# 329

# %%
temp2.count()['Name']
# Out:
# 549

# %%
# Q.10} From the cabin column seperate text adn numeric value

# %%
df["cab_char1"] = df['Cabin'].str.extract('([A-Za-z+])')  # for extracting character values from adjoin strings values in ther df columns
df['cab_num1'] = df['Cabin'].str.extract('(\d+)')  # for extracting numbers

# df

# %%
df.drop(columns = ['cab_num'],inplace=True)

# %%
df.drop(columns = 'cab_char', inplace= True)

# %%
df[['Cabin','cab_num1','cab_char1']]
# Out:
#     Cabin cab_num1 cab_char1
# 0     NaN      NaN       NaN
# 1     C85       85         C
# 2     NaN      NaN       NaN
# 3    C123      123         C
# 4     NaN      NaN       NaN
# ..    ...      ...       ...
# 886   NaN      NaN       NaN
# 887   B42       42         B
# 888   NaN      NaN       NaN
# 889  C148      148         C
# 890   NaN      NaN       NaN
#
# [891 rows x 3 columns]

# %%
##################################################################################################

# %%
# Complex datasets

# %%
# bank data

# %%
import pandas as pd
bnk = pd.read_csv("/content/drive/MyDrive/inuron python/data samples test/bank.csv", sep = ";")

# %%
bnk
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# notice that there is not uniqe id for each user
bnk['userId'] = range(1, len(bnk) + 1)
bnk.userId.unique() # works
# Out:
# array([   1,    2,    3, ..., 4519, 4520, 4521])

# %%
bnk.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y', 'userId'],
#       dtype='object')

# %%
# understanding data uci

# %%
# first understand the column attribute  and functional as[ect of data
#

# %%
bnk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
#  17  userId     4521 non-null   int64
# dtypes: int64(8), object(10)
# memory usage: 635.9+ KB

# %%
# unique values in every column\

bnk.job.unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
bnk.poutcome.unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
bnk.loan.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
bnk.previous.unique()
# Out:
# array([ 0,  4,  1,  3,  2,  5, 20,  7,  6, 10,  9,  8, 18, 19, 12, 13, 11,
#        14, 15, 24, 17, 22, 23, 25])

# %%
bnk.y.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# Q.1} how many ccampaign avilable in this this dataset

# %%
bnk.campaign.unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44])

# %%
# ==>
len(bnk.campaign.unique())
# Out:
# 32

# %%
# Q.2} how many user do we hv housing and personal loan

# %%
# loan = personal loa
# housing = housing loan

temp1 = bnk[bnk['loan'] == 'yes']
temp2 = bnk[bnk['housing'] == 'yes']

temp3 = pd.merge(temp1,temp2, on = 'userId')
temp3
# Nowtemp 3 contains all the records/people that have housing and personal loan from the bank so
# it is unlikly that the target variable is positive of these people
# Out:
#      age_x          job_x marital_x education_x default_x  balance_x  \
# 0       33       services   married   secondary        no       4789
# 1       30     management   married    tertiary        no       1476
# 2       43       services   married     primary        no        -88
# 3       31    blue-collar   married   secondary        no        360
# 4       32   entrepreneur    single     primary       yes       -849
# ..     ...            ...       ...         ...       ...        ...
# 401     42       services   married   secondary        no        -91
# 402     42    blue-collar    single   secondary        no       1080
# 403     42         admin.   married     unknown        no        642
# 404     57  self-employed   married    tertiary       yes      -3313
# 405     44   entrepreneur    single    tertiary        no       1136
#
#     housing_x loan_x contact_x  day_x  ... loan_y  contact_y  day_y  month_y  \
# ...

# %%
# both housing and personal loan shortcut

# %%
df2 = (bnk[(bnk['housing'] == "yes") & (bnk['loan'] == "yes")])
df2
# Out:
#       age            job  marital  education default  balance housing loan  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 3      30     management  married   tertiary      no     1476     yes  yes
# 9      43       services  married    primary      no      -88     yes  yes
# 14     31    blue-collar  married  secondary      no      360     yes  yes
# 48     32   entrepreneur   single    primary     yes     -849     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4502   42       services  married  secondary      no      -91     yes  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
# 4508   42         admin.  married    unknown      no      642     yes  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# Q.3} how many people who are 60+ age

# %%
bnk[bnk['age'] >= 60].count()['age']
# Out:
# 174

# %%
# Q.4} In which month we hv targeted most coustomer

# %%
bnk.y.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
bnk['month'].value_counts().max()
# Out:
# 1398

# %%
bnk['month'].value_counts().index[0]
# Out:
# 'may'

# %%
# Q.5} which mode of call is giving you moe result

# %%
cl = landed.groupby('contact').size()

# %%
cl  # cellular mode of contact is giving us most customers
# Out:
# contact
# cellular     416
# telephone     44
# unknown       61
# dtype: int64

# %%
# shortcut

temp_df = bnk.groupby(['contact','y']).count()
temp_df
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
temp_df.loc['cellular','yes']
# Out:
# age          416
# job          416
# marital      416
# education    416
# default      416
# balance      416
# housing      416
# loan         416
# day          416
# month        416
# duration     416
# campaign     416
# pdays        416
# previous     416
# poutcome     416
# Name: (cellular, yes), dtype: int64

# %%
# Q.6} how many enturprenures do we hv

# %%
bnk.job.unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
bnk[bnk['job'] == 'entrepreneur'].count()['job']
# Out:
# 168

# %%
# Q.7} how many coustomers do we hv negative balance

# %%
bnk[bnk['balance'] < 0].count()['balance']
# Out:
# 366

# %%
# Q.8} prepare a group of data on educarion level ( create seperate bunch of data for level of educatiojn)

# %%
l = bnk.education.unique()
l
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
# Primary
gp1 = bnk[bnk['education'] == 'primary']
# gp1

gp2 = bnk[bnk['education'] == "secondary"]
# gp2

gp3 = bnk[bnk['education'] == "tertiary"]
# gp3

gp4 = bnk[bnk['education'] == 'unknown']
gp4
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y  \
# ...

# %%
gp = pd.DataFrame()

for i in l:
  gp[i] = bnk[bnk['education'] == i].count()[['education','userId']]
  print(i,"group = ",gp[i])
# Out:
# primary group =  education    678
# userId       678
# Name: primary, dtype: int64
# secondary group =  education    2306
# userId       2306
# Name: secondary, dtype: int64
# tertiary group =  education    1350
# userId       1350
# Name: tertiary, dtype: int64
# unknown group =  education    187
# userId       187
# Name: unknown, dtype: int64

# %%
gp

# %%
678+2306+1350+187
# Out:
# 4521

# %%
# both housing and personal loan
