# %%
# python regx
# the str. extraction filtration syntax

# %%
# !pip install PyPDF2

# %%
import pandas as pd

import pdfplumber
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-d314d48fbcee> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 import pdfplumber
#
# ModuleNotFoundError: No module named 'pdfplumber'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
lpdf = ["/content/drive/MyDrive/inuron python/data samples test/resumes/15+ (1).pdf",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/20.pdf",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/3+.pdf",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/5+ .pdf",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/6+.pdf",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/freasher .pdf",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/mteh fresher.pdf"]

ldoc = ["/content/drive/MyDrive/inuron python/data samples test/resumes/12+.docx",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/4 .doc",
        "/content/drive/MyDrive/inuron python/data samples test/resumes/8+.docx"]

# %%
for i in lpdf:
  with pdfplumber.open(i) as pdf:
    text = ""
    for page in pdf.pages:
      text+= page.extract_text()
    print(text)
    print("##############################################################################")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d6d8c581bfab> in <cell line: 0>()
#       1 for i in lpdf:
# ----> 2   with pdfplumber.open(i) as pdf:
#       3     text = ""
#       4     for page in pdf.pages:
#       5       text+= page.extract_text()
#
# NameError: name 'pdfplumber' is not defined

# %%
type(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d31928c2d799> in <cell line: 0>()
# ----> 1 type(text)
#
# NameError: name 'text' is not defined

# %%
resume = text.split("#")
resume
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-da60f64085d0> in <cell line: 0>()
# ----> 1 resume = text.split("#")
#       2 resume
#
# NameError: name 'text' is not defined

# %%
with pdfplumber.open("/content/drive/MyDrive/inuron python/data samples test/resumes/15+ (1).pdf") as pdf:
  test = ""
  for page in pdf.pages:
    test+=page.extract_text()

test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-15ec19ab6529> in <cell line: 0>()
# ----> 1 with pdfplumber.open("/content/drive/MyDrive/inuron python/data samples test/resumes/15+ (1).pdf") as pdf:
#       2   test = ""
#       3   for page in pdf.pages:
#       4     test+=page.extract_text()
#       5
#
# NameError: name 'pdfplumber' is not defined

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# we have some Nan values
# drop all the records that have Nan values
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# by defult dropna()
# axis = 0 row  Default
# axis = 1 column

# inplace = True : permenetly drops htte records

# inplace = False : DEFAULT :it drops it but NOT permenetly
# we cna save in new var to permanently [df =df.dropna()]

# %%
# dropping column

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

# %%
df.dropna(axis = 1) # drops all the columns that has Nan Values
#  not permenetly though
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.isnull().sum()
# checking if and how mnay null values are there ?
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# no. of Nan values in a columns

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# only dropping the column with NaN records more that 10
df.dropna(axis = 1 , thresh= 800)

# this won't drop embark column
# total records 891
# if we put 800 non-Nan values are present
# thus 91 numm values are there : drop the coulmn
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
# HOW in dropna() v: any or all

# any = Default : if any Null values are present drop column/row
# all = if all the values in the column/row are Null

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

df.dropna(axis = 1, how = 'any')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

df.dropna(axis = 1, how = 'all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# fillna()
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv")

df.fillna(value = "SUDH")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# REPLACE ALL THE nAN VALUES WITH AVG(AGE)

df.fillna(value = df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# fill all the Null values in age column with avg age .mean()
# we will also learn about k means immputer

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
# Transpose operation
# .T

df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df1 = pd.read_csv("/content/drive/MyDrive/inuron python/data samples test/bank.csv", sep = ";")

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l = []
for i in df1['education'].unique():  # of every unique value in education column
  l.append(df1[df1['education'] == i])  # append a df into list l
                                      #  where educaion is equal to that instances i
                                      # i.e. that unique value in education column

# this is creating a list dataframes inside that ar seperated based on education column values

# %%
# l[0]

# %%
# l[2]

# %%
# join like sql
# concatination operation
df_0 = l[0]
df_1 = l[1]
df_2 = l[2]

# %%
"nikitas"+"siddhant?"
# Out:
# 'nikitassiddhant?'

# %%
# concatination the dataframes
pd.concat([df_0,df_1])

# but we r getting 2984 rows × 17 columns
# where a s the above datafraem do not have that many records
# this is coz it is row wise concatination i.e. axis = 0 concatination
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
# ''' so here may be we can try to take a subset of it and then
# we can try to concatination'''

# %%
df_2 = df_2.head()
df_1 = df_1.head()
#now each df has only 5 records
df_2
# Out:
#    age            job  marital education default  balance housing loan  \
# 2   35     management   single  tertiary      no     1350     yes   no
# 3   30     management  married  tertiary      no     1476     yes  yes
# 5   35     management   single  tertiary      no      747      no   no
# 6   36  self-employed  married  tertiary      no      307     yes   no
# 8   41   entrepreneur  married  tertiary      no      221     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 8   unknown   14   may        57         2     -1         0  unknown  no

# %%
df_1
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
pd.concat([df_1,df_2])

# it is concatination the df lke this

# __________
#|  df_1   |
#|_________|
#///////////
#___________
#|  df_2   |
#|_________|
#
# Out:
#     age            job  marital  education default  balance housing loan  \
# 1    33       services  married  secondary      no     4789     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# ...

# %%
# Now wht if wanna joim om axis = 1
# column wise concatination
# like this

# _________::_________
#|        |::|        |
#|  df_1  |::|  df_2  |
#|________|::|________|
#
#

# %%
pd.concat([df_1,df_2],axis = 1)
# it is joining the dataframes now but there are no common rows
# Out:
#      age          job  marital  education default  balance housing loan  \
# 1   33.0     services  married  secondary      no   4789.0     yes  yes
# 4   59.0  blue-collar  married  secondary      no      0.0     yes   no
# 7   39.0   technician  married  secondary      no    147.0     yes   no
# 10  39.0     services  married  secondary      no   9374.0     yes   no
# 11  43.0       admin.  married  secondary      no    264.0     yes   no
# 2    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 3    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 5    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 6    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 8    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
#
#      contact   day  ... loan   contact   day  month  duration campaign  pdays  \
# 1   cellular  11.0  ...  NaN       NaN   NaN    NaN       NaN      NaN    NaN
# ...

# %%
df_2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df_0 = df_0.head()[['age', 'job', 'marital']]
df_2 = df_2.head()[['age', 'job', 'marital']]
df_2
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
pd.concat([df_0,df_2]) # axis = 0 by default
# Out:
#     age            job   marital
# 0    30     unemployed   married
# 9    43       services   married
# 18   25    blue-collar    single
# 26   55    blue-collar   married
# 36   78        retired  divorced
# 2    35     management    single
# 3    30     management   married
# 5    35     management    single
# 6    36  self-employed   married
# 8    41   entrepreneur   married

# %%
pd.concat([df_0,df_2], axis = 1)
#  1  0
#  0  1|

# this looks like sql union operation but it is NOT A UNION OPERATIOPN
# Out:
#      age          job   marital   age            job  marital
# 0   30.0   unemployed   married   NaN            NaN      NaN
# 9   43.0     services   married   NaN            NaN      NaN
# 18  25.0  blue-collar    single   NaN            NaN      NaN
# 26  55.0  blue-collar   married   NaN            NaN      NaN
# 36  78.0      retired  divorced   NaN            NaN      NaN
# 2    NaN          NaN       NaN  35.0     management   single
# 3    NaN          NaN       NaN  30.0     management  married
# 5    NaN          NaN       NaN  35.0     management   single
# 6    NaN          NaN       NaN  36.0  self-employed  married
# 8    NaN          NaN       NaN  41.0   entrepreneur  married

# %%
df5 = pd.concat([df_0,df_2], axis = 1)

# %%
df5['age']
# Out:
#      age   age
# 0   30.0   NaN
# 9   43.0   NaN
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN
# 2    NaN  35.0
# 3    NaN  30.0
# 5    NaN  35.0
# 6    NaN  36.0
# 8    NaN  41.0

# %%
# iloc /: Integer loc

# difference between loc and iloc is
# loc try to take named indexes and
# iloc takes integer/inbuilt one

# iloc only considers the internal default indexing no matter the key in the df

# %%
# df.iloc[row values, column values]

# %%
df5.iloc[:,3]
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 2     35.0
# 3     30.0
# 5     35.0
# 6     36.0
# 8     41.0
# Name: age, dtype: float64

# %%
# multiple columns using iloc

df5.iloc[:,[3,4,5]]
# Out:
#      age            job  marital
# 0    NaN            NaN      NaN
# 9    NaN            NaN      NaN
# 18   NaN            NaN      NaN
# 26   NaN            NaN      NaN
# 36   NaN            NaN      NaN
# 2   35.0     management   single
# 3   30.0     management  married
# 5   35.0     management   single
# 6   36.0  self-employed  married
# 8   41.0   entrepreneur  married

# %%
df5.iloc[[5,6],[3,4]]
# Out:
#     age         job
# 2  35.0  management
# 3  30.0  management

# %%
df5.iloc[[8,9],[3,4]]
# iloc only considers the internal default indexing no matter the key in the df
# that why we r not geting the record with id == 9 in thtis cell
# Out:
#     age            job
# 6  36.0  self-employed
# 8  41.0   entrepreneur

# %%
# this wont work for iloc
df5[:,'age']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 'age')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-58-c71e288ee707> in <cell line: 0>()
#       1 # this wont work for iloc
# ----> 2 df5[:,'age']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
# ...

# %%
df5.loc[[8,9]]
# Out:
#     age       job  marital   age           job  marital
# 8   NaN       NaN      NaN  41.0  entrepreneur  married
# 9  43.0  services  married   NaN           NaN      NaN

# %%
df5.iloc[[8,9]]
# Out:
#    age  job marital   age            job  marital
# 6  NaN  NaN     NaN  36.0  self-employed  married
# 8  NaN  NaN     NaN  41.0   entrepreneur  married

# %%
# notice the difference between loca and iloc above regarding the indexing considaration

# %%
df5.loc[[8,9],'age']
# Out:
#     age   age
# 8   NaN  41.0
# 9  43.0   NaN

# %%
df5.iloc[[8,9],3]
# Out:
# 6    36.0
# 8    41.0
# Name: age, dtype: float64

# %%
# extracting perticular data from df

df_0
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
# extracting perticular data from df
# iloc

df_0.iloc[[1,2],[1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
# extracting perticular data from df
# loc

df5.loc[[9,18],['job','marital']]
# Out:
#             job  job  marital marital
# 9      services  NaN  married     NaN
# 18  blue-collar  NaN   single     NaN

# %%
df_0.iloc[[1,2],[0,2]]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
df_0.loc[[9,18],['age','marital']]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
df_2
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
df_1
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
# Mearge ooperation

# %%
df_0 = df_0.head()[['age', 'job', 'marital']]
df_1 = df_1.head()[['age', 'job', 'marital']]
df_2 = df_2.head()[['age', 'job', 'marital']]

# %%
pd.merge(df_1,df_2)
# Why cant we see any merge ?
# ==>  how and on param.
# on param inside merge : on = 'column name"
# Out:
# Empty DataFrame
# Columns: [age, job, marital]
# Index: []

# %%
# for example
# if we try to merge on "age" column

pd.merge(df_0,df_1, on = 'age')
# ''' it will check if there is any any age value mathces to the one
# in the 2md column age column'''

#''' then it will meargein that perticulat valueand take other column values
# from both the df and name htem _x and _y for each var
# like shown bello :job_x	marital_x	job_y	marital_y '''
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
# how param inside merge :
#

pd.merge(df_0,df_1, on = 'age', how = "left")
# takes all values from left table and only the mathced values from right/second df
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
pd.merge(df_0,df_1, on = 'age', how = 'right')
# takes all columns from right/ 2nd table and only the mathced values from first/left df
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
df_0
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df_1
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
pd.merge(df_0,df_1, on = 'age', how = 'inner')
# by default it gives us intersection of both table
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df_0,df_1,on = 'age', how = 'outer')
# outer select everythin
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   25  blue-collar    single          NaN       NaN
# 1   30   unemployed   married          NaN       NaN
# 2   33          NaN       NaN     services   married
# 3   39          NaN       NaN   technician   married
# 4   39          NaN       NaN     services   married
# 5   43     services   married       admin.   married
# 6   55  blue-collar   married          NaN       NaN
# 7   59          NaN       NaN  blue-collar   married
# 8   78      retired  divorced          NaN       NaN

# %%
# how erge and jion are different
# sntax ofr df join :

# DataFrame_1.join(DataFrame_2)

# rules: 1) the column names sould not overlap in both df
#        2) the df shoul hv indexes

df_0.join(df_1, on = 'age')
# this work
# Out:
#              job   marital        job1 marital1
# age
# 30    unemployed   married  management  married
# 43      services   married         NaN      NaN
# 25   blue-collar    single         NaN      NaN
# 55   blue-collar   married         NaN      NaN
# 78       retired  divorced         NaN      NaN

# %%
df_1 =df_2.set_index('age')
df_0 = df_0.set_index("age")

# %%
df_0
# Out:
#              job   marital
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
# now lets try again

df_0.join(df_1,on = 'age')

# this also wont work coz the column names are same
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-4172f44e14d7> in <cell line: 0>()
#       1 # now lets try again
#       2
# ----> 3 df_0.join(df_1,on = 'age')
#       4
#       5 # this also wont work coz the column names are same
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10755                     validate=validate,
#   10756                 )
# > 10757             return merge(
#   10758                 self,
#   10759                 other,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     182             validate=validate,
#     183         )
# --> 184         return op.get_result(copy=copy)
#     185
#     186
#
# ...

# %%
# renaming the columns

df_1.rename(columns={"job":"job1","marital": "marital1"},inplace= True)

# %%
df_1
# Out:
#               job1 marital1
# age
# 35      management   single
# 30      management  married
# 35      management   single
# 36   self-employed  married
# 41    entrepreneur  married

# %%
# now joining

df_0.join(df_1)
# Out:
#              job   marital        job1 marital1
# age
# 30    unemployed   married  management  married
# 43      services   married         NaN      NaN
# 25   blue-collar    single         NaN      NaN
# 55   blue-collar   married         NaN      NaN
# 78       retired  divorced         NaN      NaN

# %%
# diffenrece between merge and join is very small
# they are almost the same
# the only differenc is ;
# .merge takes 'on = ' param. all the time
# .join takes the indexes as on = by defaul so we dont hv to mention it.

# in my opinion merge is more fisible coz : 1)allows u to keep overlapping column name

# %%
df_0.join(df_1, how = 'inner')
# Out:
#             job  marital        job1 marital1
# age
# 30   unemployed  married  management  married

# %%
tempdf = df_0.join(df_1, how = 'inner')
tempdf
# Out:
#             job  marital        job1 marital1
# age
# 30   unemployed  married  management  married

# %%
tempdf.transpose()
# Out:
# age               30
# job       unemployed
# marital      married
# job1      management
# marital1     married

# %%
# resetitng the indexes
df_1 = df_1.reset_index()

# %%
df_0 = df_0.reset_index()

# %%
df_0.age
# Out:
# 0    30
# 1    43
# 2    25
# 3    55
# 4    78
# Name: age, dtype: int64

# %%
df_0['age']
# Out:
# 0    30
# 1    43
# 2    25
# 3    55
# 4    78
# Name: age, dtype: int64

# %%
# difference between count() and value_counts()

# .value_counts() : does group and count operation

# count() :just count it

# %%
df_0
# Out:
#    age          job   marital
# 0   30   unemployed   married
# 1   43     services   married
# 2   25  blue-collar    single
# 3   55  blue-collar   married
# 4   78      retired  divorced

# %%
df_0['age'].count()
# Out:
# 5

# %%
df_0.marital.value_counts()

# pruping by the marage stat
# Out:
# marital
# married     3
# single      1
# divorced    1
# Name: count, dtype: int64
