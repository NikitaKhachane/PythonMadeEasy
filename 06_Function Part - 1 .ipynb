# %%
len("nikita")
# Out:
# 6

# %%
# len is a function

# %%
print("hhhhh")
# Out:
# hhhhh

# %%
# moduler cooding

# %%
# def keyword to define a function
#

# %%
def test():

# a function ca not a blank
# Out:
#   File "<ipython-input-8-dc659fc0b381>", line 3
#     # a function ca not a blank
#                                ^
# SyntaxError: incomplete input

# %%
def test():
  pass

# %%
def test1():
  print("this is my first function")
#   even if the function is created & it is correct
# nothing will happne untill you call it

# %%
# how to call a function

test1()
# Out:
# this is my first function

# %%
def test_2():   # defining a function
  print("2nd function")  # funcion body

a = test_2() # creating variable for a function
a  # calling a funciton

#return type of a funtion
# variable a isholding output of the function test_2
# Out:
# 2nd function

# %%
# so a hold a string
# but

a + "nikita"  # string concatination
# NoneType + String
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e1282d994b2e> in <cell line: 4>()
#       2 # but
#       3
# ----> 4 a + "nikita"  # string concatination
#       5 # NoneType + String
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
# it does not work coz the value a hold is 'NoneType'

type(a)
# Out:
# NoneType

# %%
type(test_2())
# Out:
# 2nd function
# NoneType

# %%
str(a)
# Out:
# 'None'

# %%
# To solve the problem

def test_2():
  return "this is my 1st function"
  #(   return is a keyword that is iused to pass the value
  # in the same datatype as it is and not 'NoneType')

a = test_2()
a
# Out:
# 'this is my 1st function'

# %%
type(test_2)
# Out:
# function

# %%
a+"_____nikita"
# Out:
# 'this is my 1st function_____nikita'

# %%
type(test_2())
# Out:
# str

# %%
def test():
  return 876946

test()
# Out:
# 876946

# %%
type(test())
# Out:
# int

# %%
def test4():
  return 4,3,"nik",[4,5,6]

test4()
# by default funtion will retur a TUPLE if
# there are multiple valus to return

b = test4()
b
# Out:
# (4, 3, 'nik', [4, 5, 6])

# %%
b[0]
# Out:
# 4

# %%
b[2]
# Out:
# 'nik'

# %%
# to hold all values in different variables

a = 1
b = 5
c="nik"

# %%
a,b,c = 4,6,'mij'
a
# Out:
# 4

# %%
# NOT a Dynamic approach

def test4():
  return 4,66.6,"nnikita",[3,'r',7]

# make sure the number of variable and no.
# of values is same in this case

u,v,x,y = test4()
print("u = ",u,"\nv = ",v,"\n x = ",x,"\n y = ",y)
# Out:
# u =  4
# v =  66.6
#  x =  nnikita
#  y =  [3, 'r', 7]

# %%
# operation in funtion

def test5():
  a = 6*7/6
  return a

test5()
# Out:
# 7.0

# %%
# pass a vlaue in a funtion

def test6(l):
  k = []
  for i in l:
    if type(i) == int:
      k.append(i)
    else:pass
  return k


#l = [3,4,5,6,6,88,"niki",[5,5,5,5]]
l = (3,4,5,6,6,88,"niki",[5,5,5,5])

test6(l)
  # this should only work in case if user pass a list
  # This code also works for tuple if we pass it
  # thuis folloeing code fixes that
# Out:
# [3, 4, 5, 6, 6, 88]

# %%
def test_7(l):
  k = []
  if type(l) == list:
    for i in l:
      if type(i) == int:
        k.append(i)
      else:pass
  else:
    return "TypeError : funtion does not accept 'Tuple' object"
  return k

#l = input("Input a list : ")
#l = [3,4,5,6,6,88,"niki",[5,5,5,5]]
l = (3,4,5,6,6,88,"niki",[5,5,5,5])

test_7(l)

# This Function will only work if we pass a list datatype
# Out:
# "TypeError : funtion does not accept 'Tuple' object"

# %%
# same code above with list

def test_7(l):
  k = []
  if type(l) == list:
    for i in l:
      if type(i) == int:
        k.append(i)
      else:pass
  else:
    return "TypeError : funtion does not accept 'Tuple' object"
  return k

#l = input("Input a list : ")
l = [3,4,5,6,6,88,"niki",[5,5,5,5]]
#l = (3,4,5,6,6,88,"niki",[5,5,5,5])

test_7(l)

# This Function will only work if we pass a list datatype
# Out:
# [3, 4, 5, 6, 6, 88]

# %%
test_7()
# functiona wiill not work until you pass somethin in it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-65e0266469c0> in <cell line: 1>()
# ----> 1 test_7()
#       2 # functiona wiill not work until you pass somethin in it
#
# TypeError: test_7() missing 1 required positional argument: 'l'

# %%
test_7(l,l)
# the number of pasing element shoul not be extra or less
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-b3a898d6ee9f> in <cell line: 1>()
# ----> 1 test_7(l,l)
#       2 # the number of pasing element shoul not be extra or less
#
# TypeError: test_7() takes 1 positional argument but 2 were given

# %%
type(test_7(l))
# Out:
# list

# %%
def test_7(l):
  k = []
  if type(l) == list:
    for i in l:
      if type(i) == int:
        k.append(i)
      elif type(i) == list:
        for j in i:
          if type(j) == int:
            k.append(j)
          else:pass
      else:pass
  else:
    return "TypeError : funtion does not accept 'Tuple' object"
  return k

#l = input("Input a list : ")
l = [3,4,5,6,6,88,"niki",[5,5,5,5]]
#l = (3,4,5,6,6,88,"niki",[5,5,5,5])

test_7(l)

# This Function will only work if we pass a list datatype
# Out:
# [3, 4, 5, 6, 6, 88, 5, 5, 5, 5]

# %%
a = [6,5,3,2,(7,5,3.6),"hhh"]
b = ['yyy',"vvv","jjjj"]
c = {7,6,5,4,3,3,55,7}
test_7(a)
test_7(b)
test_7(c)
# Out:
# "TypeError : funtion does not accept 'Tuple' object"

# %%
def test_7(l):
  k = []
  if type(l) == list:
    for i in l:
      if type(i) == int:
        k.append(i)
      elif type(i) == list:
        for j in i:
          if type(j) == int:
            k.append(j)
          else:pass
      else:pass
  else:
    return "TypeError : funtion does not accept 'Tuple' object"
  return k

#l = input("Input a list : ")
#l = [3,4,5,6,6,88,"niki",[5,5,5,5]]
#l = (3,4,5,6,6,88,"niki",[5,5,5,5])

l = input("enter a list : ")

test_7(l)

# This Function will only work if we pass a list datatype
# Out:
# enter a list : [3,4,5,6,6,88,"niki",[5,5,5,5]]
# "TypeError : funtion does not accept 'Tuple' object"

# %%
#take a dict as input
# return all keys

def test8(c):
  l = []
  if type(c) == dict:
    return c.keys()
  else:
    return "Not a dict"

# %%
test8("nikita")
# Out:
# 'Not a dict'

# %%
di = {1:"nnik",2:"hhh","jk":"gojo"}

test8(di)
# Out:
# dict_keys([1, 2, 'jk'])

# %%
# take multiple inputs
# return a list after expanding it
# if not a list say a msg

def test9(a,b):
  l = []
  if type(a) == list and type(b) == list:
    a.extend(b)
    return a
  else:
    return "invalid input"

test9(5656,"nik")
# Out:
# 'invalid input'

# %%
p = test9([6,7,8],["nik","ggg"])
p
# Out:
# [6, 7, 8, 'nik', 'ggg']

# %%
def test10(m):
  for i in range(m+1):
    print(" *"*i)

test10(3)
# Out:
#  *
#  * *
#  * * *

# %%
test10(10)
# Out:
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * * * *
#  * * * * * * *
#  * * * * * * * *
#  * * * * * * * * *
#  * * * * * * * * * *

# %%
def test11(n):
  for i in range(n+1):
    print("  "*((n+1)-i),"  * "*i)


test11(7)
# Out:
#
#                  *
#                *   *
#              *   *   *
#            *   *   *   *
#          *   *   *   *   *
#        *   *   *   *   *   *
#      *   *   *   *   *   *   *

# %%
test11(12)
# Out:
#
#                            *
#                          *   *
#                        *   *   *
#                      *   *   *   *
#                    *   *   *   *   *
#                  *   *   *   *   *   *
#                *   *   *   *   *   *   *
#              *   *   *   *   *   *   *   *
#            *   *   *   *   *   *   *   *   *
#          *   *   *   *   *   *   *   *   *   *
#        *   *   *   *   *   *   *   *   *   *   *
#      *   *   *   *   *   *   *   *   *   *   *   *

# %%
# creating docstring for ur function (uses triple quuotes)

def test11(n):
  """function will help you to create a triangle whith any no. of stars as base"""
  for i in range(n+1):
    print("  "*((n+1)-i),"  * "*i)


test11(7)
# Out:
#
#                  *
#                *   *
#              *   *   *
#            *   *   *   *
#          *   *   *   *   *
#        *   *   *   *   *   *
#      *   *   *   *   *   *   *

# %%
help(test11)
# Out:
# Help on function test11 in module __main__:
#
# test11(n)
#     function will help you to create a triangle whith any no. of stars as base

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# 1) write a function thst takes a string and return a len of it without using in built fun len
# 2) write a fun wich will be able to print an index of all elements which you will pass
# 3) ewrite a fun that takes a nested dict and return it as a list of all values
# 4) write a fun that takes another fun as input ans return o/p
# 5) write a fun which will take list as input and give concatinaiton of all the elements
# 6) write a fun hich will be able to tke list i/p and return index of each element like inbuilt fun but even if we hv repetative elements it should return index
# 7) 7. Write a function which will whould return list of all the file name from a directory.

# 8 write a function which will be able to show your system configuration

#9. write a function which will be able to show date and time

#10. write a function whihc will be able to read a image file and show it to you

#11 write a function which can read video file and play for you

#12 write a function whihc can move a file from one directory to another directory

#13 write a function which will be able to shutdonw your system

#14 write a function whihc will be able to access your mail

#15. write a func bywhcih i can send a mail to anyone

#16. write a func to read a complete PDF file

#17. write a function to read a word file

#18 write a function which can help you to filter only word file from a directory

#19. write a function by which you can print an ip address of your system

#20. write a function by whihc you will be able to append two PDF files.

# %% [markdown]
# **1. you have to write a fun which will take string and return a len of it without using a inbuilt fun len
#
# 2. write a fun which will be able to print an index of all premitive element which you will pass
#
# 3. Write a fun which will take input as a dict and give me out as a list of all the values even in case of 2 level nesting it should work.
#
# 4. write a fun which will take another function as an input and return me an output
#
# 5. write a function whihc will take multiple list as a input and give me concatnation of all the e and output
#
# 6. write a function which will be able to take a list as an input return an index of each element like a inbuilt index function but even if we have repetative element it should return index
#
# 7. Write a function which will whould return list of all the file name from a directory
#
# 8 write a function which will be able to show your system configuration
#
# 9. write a function which will be able to show date and time
#
# 10. write a function whihc will be able to read a image file and show it to you
#
# 11 write a function which can read video file and play for you
#
# 12 write a function whihc can move a file from one directory to another directory
#
# 13. write a function which will be able to shutdonw your system
#
# 14. write a function whihc will be able to access your mail.
#
# 15 write a func bywhcih i can send a mail to anyone
#
# 16. write a func to read a complete PDf file
#
# 17. write a function to read a word file.
#
# 18 write a function which can help you to filter only word file from a directory
#
# 19. write a function by which you can print an ip address of your system
#
# 20. write a function by whihc you will be able to append two PDF files**

# %%
# solution fo rabove question are in a seperate file
# file name :-

# 08_pyhton basic - function practice questions
