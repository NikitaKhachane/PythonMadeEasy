# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# scatter in seaborn

sns.scatterplot(x = df.sepal_length,y = df.petal_length)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
import matplotlib.pyplot as plt

plt.plot(df.sepal_length, df.petal_length, 'o')

# the results are exactly same

# %%
plt.plot(df.sepal_length, df.petal_length, 'o')
plt.xlabel("sep_len")
plt.ylabel("pet_len")
# Out:
# Text(0, 0.5, 'pet_len')

# %%
plt.hist(df['sepal_length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['sepal_length'], alpha = 0.5)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot((df['sepal_length']))
# Out:
# <ipython-input-16-985597f1fdea>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((df['sepal_length']))
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
df1 = sns.load_dataset("tips")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# is there a  relation between totale bil and tip

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df1)
# yes corellated and increse together
# buit there a realos cases when bils are too low but the tips are high
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df1["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
# in same scatterplot plot smoer also

sns.relplot(x= 'total_bill', y = 'tip',data = df1, hue = 'smoker')  # hue is basiccaly groupbyoperation

# %%
sns.relplot(x= 'total_bill', y = 'tip',data = df1, style = 'smoker')

# %%
sns.relplot(x= 'total_bill', y = 'tip',data = df1, style = 'size')  # size of the group it means

# %%
sns.relplot(x= 'total_bill', y = 'tip',data = df1, hue = 'size')  # size of the group it means

# %%
sns.relplot(x= 'total_bill', y = 'tip',data = df1, hue = 'time')  # size of the group it means

# %%
# group by base d on 2 different columns

sns.relplot(x = 'total_bill', y = 'tip', data = df1, style = 'time', hue = 'smoker')

# %%
sns.relplot(x= 'total_bill', y = 'tip',data = df1, size = 'size')  # size of the group it means

# %%
sns.relplot(x = 'total_bill', y = 'tip', kind ='line', data =df1)
# if we connect all dots from above cell we will get the output of thiss cell

# %%
# one graph for lunch 1 for dinner

# 2 graphs

sns.relplot(x = 'total_bill', y = 'tip', col = 'time', data = df1)

# %%
sns.relplot(x = 'total_bill', y = 'tip', col = 'day', data = df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# catagoricalplot
sns.catplot(x = 'day', y = 'total_bill', data = df1, hue="day")

# %%
 sns.catplot(x = 'day', y = 'tip', data = df1, kind = 'swarm', hue = 'day')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
 sns.catplot(x = 'day', y = 'tip', data = df1, kind = 'box', hue = 'sex')
 # saturday had most high tips # most outliers

# %%
sns.pairplot(df)  # all columns vs all columns
