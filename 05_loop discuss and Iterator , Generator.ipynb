# %%
s = "this is a basic ppython calss"
# no of letter

count = 0

for i in s:
  count+=1
  #count = count+1

count # inclede the spaces
# Out:
# 29

# %%
# string in reverse order
s[::-1]
# Out:
# 'sslac nohtypp cisab a si siht'

# %%
len(s)
# Out:
# 29

# %%
for i in range((len(s)-1),-1,-1):
  print(s[i])
# Out:
# s
# s
# l
# a
# c
#
# n
# o
# h
# t
# y
# p
# p
#
# c
# i
# s
# a
# b
#
# a
#
# s
# i
#
# s
# i
# h
# t

# %%
i = len(s)-1
print("i = ",i)
while i < (len(s)) and  i >= 0:
  print(s[i])
  i-=1
# Out:
# i =  28
# s
# s
# l
# a
# c
#
# n
# o
# h
# t
# y
# p
# p
#
# c
# i
# s
# a
# b
#
# a
#
# s
# i
#
# s
# i
# h
# t

# %%
i = len(s) - 1

while i < (len(s)) and i >= 0:
  print(s[i])
  i-=1
# Out:
# s
# s
# l
# a
# c
#
# n
# o
# h
# t
# y
# p
# p
#
# c
# i
# s
# a
# b
#
# a
#
# s
# i
#
# s
# i
# h
# t

# %%
mo = "jiya"

# reverse print()
n= "" # empty string
l = len(mo) - 1
while  l>=0:
  print(mo[l])
  n = n + mo[l]
  l-=1

print(n)
# Out:
# a
# y
# i
# j
# ayij

# %%
n
# Out:
# 'ayij'

# %%
i = len(mo) - 1

while (i >= 0):
  print(mo[i],end=" ")
  i-=1
# Out:
# a y i j

# %%
s = "ineuron"
v = "AaEeIiOoUu"

for k in s:
  if k in v:
    print(i," => is a vowel")
  else: print(i," => NOT")
# Out:
# n  => is a vowel
# n  => NOT
# n  => is a vowel
# n  => is a vowel
# n  => NOT
# n  => is a vowel
# n  => NOT

# %%
# pelindrom = navjeevan in marathi
# eye
# malayalam
# tnent

# check if the string is pelendom or not

# %%
s = input("")

if s == s[::-1]:
  print('pelindrom')
else: print("NOT")
# Out:
# tnent
# pelindrom

# %%
s = input("")

for i in range(len(s)):
  print(s[i],' <==> ',s[len(s)-1-i])
  print(i,' <==> ',(len(s)-1-i))
  if s[i] == s[len(s)-1-i]:

    continue
  else:
    print("not")
else:
  print("Pelindrome")
# Out:
# nikita
# n  <==>  a
# 0  <==>  5
# not
# i  <==>  t
# 1  <==>  4
# not
# k  <==>  i
# 2  <==>  3
# not
# i  <==>  k
# 3  <==>  2
# not
# t  <==>  i
# 4  <==>  1
# not
# a  <==>  n
# 5  <==>  0
# not
# Pelindrome

# %%
s = input("input a string : ")

for i in range(len(s)):
  if s[i] != s[len(s)-1-i]:
    print("NOT")
    break
else:print("pelindrome")
# Out:
# input a string : tnknt
# pelindrome

# %%
s = input("input a string:")

i = 0

while i < len(s):
  if s[i] != s[len(s) - 1 - i]:
    print('NON')
    break
  i+=1
else:
  print("elindrome")
# Out:
# input a string:pikaso
# NON

# %%
s = input("")

bs = ""

c = len(s)-1

while i < len(s):
  bs = bs + s[i]
  i+=1

if bs == s:
  print("Pelindrome")
else:print("NOT pelindrome")
# Out:
# kite
# NOT pelindrome

# %%
s
# Out:
# 'kite'

# %%
s = input("")
bs = ""

for i in s:
  bs = bs + i

if bs == s:
  print("pelindrome")
else:print("NOT")
# Out:
# mkoiuygh
# pelindrome

# %% [markdown]
# **dict**

# %%
d = {"india":"IN",
     "canada":"CA",
     "china":"CH",
     "uniited states":"US"}

"india" in d
# Out:
# True

# %%
"IN" in d.values()
# Out:
# True

# %%
l1 = []
l2 = []

for i in d.keys():
  if len(i)> 5:
    l1.append(i)
  elif len(i) <= 5:
    l2.append(i)

# %%
l1
# Out:
# ['canada', 'uniited states']

# %%
l2
# Out:
# ['india', 'china']

# %%
d1 = {
    "ineruon": {"a":14,
                "b":10,
                "c":4},
    "course":  {"d":45,
                 "e":34,
                 "f":1
                }
}

for i in d1:
  print("max in ",i," is ",max(d1[i].values()))
# Out:
# max in  ineruon  is  14
# max in  course  is  45

# %%
d1['ineruon'].keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d1["ineruon"].values()
# Out:
# dict_values([14, 10, 4])

# %%
max(2,4,6)
# Out:
# 6

# %%
d_1 = {"ineuron":{"a":14,"b":10,"c":4},
       "course":{"d":45,"e":34,"f":1},
       "G" : 34,
       "H" : [45,6,7,8,9,3],
       " I" : (47,34,2),
       "K" : "nikita"}

# %%
d_1.items()
# Out:
# dict_items([('ineuron', {'a': 14, 'b': 10, 'c': 4}), ('course', {'d': 45, 'e': 34, 'f': 1}), ('G', 34), ('H', [45, 6, 7, 8, 9, 3]), (' I', (47, 34, 2)), ('K', 'nikita')])

# %%
for i in d_1.values():
  print(i)
# Out:
# {'a': 14, 'b': 10, 'c': 4}
# {'d': 45, 'e': 34, 'f': 1}
# 34
# [45, 6, 7, 8, 9, 3]
# (47, 34, 2)
# nikita

# %%
for i in d_1.values():
  print(type(i))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'int'>
# <class 'list'>
# <class 'tuple'>
# <class 'str'>

# %%
el = []

for i in d_1.values():
  if type(i) == dict:
    el.append(max(i.values()))
  elif type(i) == int:
    el.append(i)
  elif type(i) == list:
    el.append(max(i))
  elif type(i) == tuple:
    el.append(max(i))
  elif type(i) == str:
    pass
  elif type(i) == complex:
    pass
  else:
    pass


print("Max of all the integer in this dictionary is ",max(el))
# Out:
# Max of all the integer in this dictionary is  47
