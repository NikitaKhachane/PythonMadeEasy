# %% [markdown]
# **Tuple**

# %%
# tuple is immutable
# tuple do not contain duplicate values
# notation for tuple is ()

# %%
t = (1,2,3,4,5)
type(t)
# Out:
# tuple

# %%
t= (1,2.3,"nik",45+3j,True)
type(t)
# Out:
# tuple

# %%
l = [1,2.3,"nik",45+3j,True]
type(l)
# Out:
# list

# %%
t2 = ()
type(t2)
# Out:
# tuple

# %%
t= (1 , 2.3 , "nik" , 45+3j , True )

# %%
l[0:2]
# Out:
# [1, 2.3]

# %%
t[0:2]
# slicing wise both list and tuple are used same logic(usce squar bracket)
# Out:
# (1, 2.3)

# %%
t[::-1]
# Out:
# (True, (45+3j), 'nik', 2.3, 1)

# %%
t[-1]
# Out:
# True

# %%
t[0::2]
# Out:
# (1, 'nik', True)

# %%
# differences-
# immutable

# %%
l
# Out:
# [1, 2.3, 'nik', (45+3j), True]

# %%
l1 = [2,3,4,5]

# %%
l[0]
# Out:
# 1

# %%
l[0]= 'kumsr'
l
# Out:
# ['kumsr', 2.3, 'nik', (45+3j), True]

# %%
t
# Out:
# (1, 2.3, 'nik', (45+3j), True)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'hjj'
t
# immuatable thius can not change
# TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2d7d8f348b37> in <cell line: 1>()
# ----> 1 t[0] = 'hjj'
#       2 t
#       3 # immuatable thius can not change
#       4 # TypeError: 'tuple' object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2 = (2,3,4,554,4)

# %%
t + t2
# works like append operation in list
# Out:
# (1, 2.3, 'nik', (45+3j), True, 2, 3, 4, 554, 4)

# %%
t * 2
# Tuple/
# Out:
# (1, 2.3, 'nik', (45+3j), True, 1, 2.3, 'nik', (45+3j), True)

# %%
l
# Out:
# ['kumsr', 2.3, 'nik', (45+3j), True]

# %%
l*2
# List
# Out:
# ['kumsr', 2.3, 'nik', (45+3j), True, 'kumsr', 2.3, 'nik', (45+3j), True]

# %%
t1 = (1, 2.3, 'nik', (45+3j), True , 0)
t3 = t1 = (1, 2.3, 'nik', (45+3j), True , 0 , False)

# %%
t1.count(2.3)
# Out:
# 1

# %%
t1.count(1)
# counts True as 1
# Out:
# 2

# %%
t1.count(0)
# Out:
# 2

# %%
t3.count(0)
# counts false as 0
# Out:
# 2

# %%
# Why do we need tuples ?
# data sceurity , online accounts passwords etc.
# fixed sized collection

# %%
t = (45,2,43,45,4, (2,3,4), 'dddd')
# nested tuple

# %%
t1 = ( [1,2,3] , (4,5,6) )
# list inside tuple

# %%
t1[1][0]
#the item in tuple itself can not be changed
# / but inside that if there is an datatype which supports mitability it can be changed/updated
# Out:
# 4

# %%
t1[0][1] = 'nik'
t1
# here it works
# Out:
# ([1, 'nik', 3], (4, 5, 6))

# %%
t1[0] = "reassign"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-4793d72607bb> in <cell line: 1>()
# ----> 1 t1[0] = "reassign"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# can not add tuple nad list as it is heterogeneous and homogeneous

# %%
# data conversion

# %%
t
# Out:
# (45, 2, 43, 45, 4, (2, 3, 4), 'dddd')

# %%
l1 = list(t)
l1
# Out:
# [45, 2, 43, 45, 4, (2, 3, 4), 'dddd']

# %%
t5 = tuple(l)
t5
# Out:
# ('kumsr', 2.3, 'nik', (45+3j), True)

# %%
#############################################################################################

# %% [markdown]
# **Set**

# %%
l = [1,1,1,2,2,2,2,6,5,5,6,7,7,6,5,4,4,4,3,4,4,]

# %%
# removing all duplicates

# %%
s = set(l)
s
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
print("hi")
# Out:
# hi

# %%
t+t1
# Out:
# (45, 2, 43, 45, 4, (2, 3, 4), 'dddd', [1, 'nik', 3], (4, 5, 6))

# %%
t1
# Out:
# ([1, 'nik', 3], (4, 5, 6))

# %%
t2
# Out:
# (2, 3, 4, 554, 4)

# %%
t
# Out:
# (45, 2, 43, 45, 4, (2, 3, 4), 'dddd')

# %%
t = (1, 2.3, 'nik', (45+3j), True)

# %%
t.count(1)
# Out:
# 2

# %%
t.index(2.3)
# Out:
# 1

# %%
t1 = ([3,2,1],3)

# %%
t
# Out:
# (1, 2.3, 'nik', (45+3j), True)

# %%
t = (1, 2.3, 'nik', (45+3j), True, [2,2,4,5])

# %%
t
# Out:
# (1, 2.3, 'nik', (45+3j), True, [2, 2, 4, 5])

# %%
t[-1][0] = 'nkk'
t
# Out:
# (1, 2.3, 'nik', (45+3j), True, ['nkk', 2, 4, 5])

# %%
t[0] = 'mim'
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-89ce3aece604> in <cell line: 1>()
# ----> 1 t[0] = 'mim'
#       2 t
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ** SET **

# %%
l = [5,4,3,2,5,4,3,3,3,2,4,5,6,6,6,7,7,76,8,995,43,22,1,22,3,4,5]

# %%
l
# Out:
# [5,
#  4,
#  3,
#  2,
#  5,
#  4,
#  3,
#  3,
#  3,
#  2,
#  4,
#  5,
#  6,
#  6,
#  6,
#  7,
#  7,
#  76,
#  8,
#  995,
#  43,
#  22,
#  1,
#  22,
#  3,
#  4,
#  5]

# %%
ls = set(l)

# %%
ls
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 22, 43, 76, 995}

# %%
type(ls)
# Out:
# set

# %%
ns = {3,4,4,5,61,41,3,61,4}
# it will remove all thhe duplicates
# it keeps a sigle coopy of the element

# %%
ns
# Out:
# {3, 4, 5, 41, 61}

# %%
type(ns)
# Out:
# set

# %%
s = {}
type(s)
# Out:
# dict

# %%
nss = {1,2,3}
type(nss)
# Out:
# set

# %%
ns
# Out:
# {3, 4, 5, 41, 61}

# %%
ns[0]
# it does not support indexation
#  'set' object is not subscriptable]
# set is an unordered collection
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-d622329ab691> in <cell line: 1>()
# ----> 1 ns[0]
#       2 # it does not support indexation
#       3 #  'set' object is not subscriptable]
#       4 # set is an unordered collection
#
# TypeError: 'set' object is not subscriptable

# %%
ns
# Out:
# {3, 4, 5, 41, 61}

# %%
l = list(ns)
l[0]
# Out:
# 3

# %%
ns
# Out:
# {3, 4, 5, 41, 61}

# %%
ns.add(333)
ns
# Out:
# {3, 4, 5, 41, 61, 333}

# %%
ns.add('nj')
ns
# Out:
# {3, 333, 4, 41, 5, 61, 'nj'}

# %%
ns.add([1,2,3])
ns
# can not add a list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-348e40d3b8f5> in <cell line: 1>()
# ----> 1 ns.add([1,2,3])
#       2 ns
#       3 # can not add a list
#
# TypeError: unhashable type: 'list'

# %%
ns
# Out:
# {3, 333, 4, 41, 5, 61, 'nj'}

# %%
# set always holds an unorderd collection of an unique element
# thus it can not hold a MUTABLEttable collection (list) of elments

# %%
s = {(2,3,4),4,3,3,4,5,6,6,663,5,6,64}
s
# Out:
# {(2, 3, 4), 3, 4, 5, 6, 64, 663}

# %%
s
# Out:
# {(2, 3, 4), 3, 4, 5, 6, 64, 663}

# %%
ns
# Out:
# {3, 333, 4, 41, 5, 61, 'nj'}

# %%
ns.remove(333)

# %%
ns
# Out:
# {3, 4, 41, 5, 61, 'nj'}

# %%
ns.discard(41)
# removes element if it is a member
# if eelement is not a member, do nothing

# %%
ns
# Out:
# {3, 4, 5, 61, 'nj'}

# %%
# Difference between remove and discard
#

# %%
ns.remove(54)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-158d94eb9775> in <cell line: 1>()
# ----> 1 ns.remove(54)
#
# KeyError: 54

# %%
ns.discard(54)

# %%
ns
# Out:
# {3, 4, 5, 61, 'nj'}

# %%
{"sudh","Sudh"}
# Out:
# {'Sudh', 'sudh'}

# %% [markdown]
# **Dictionary**

# %% [markdown]
# **============================================================**

# %%
d = {}
type(d)
# Out:
# dict

# %%
# Dictinary have key and value pairs
# keys will nor duplicate
# key is  unique

# %%
d = {4 : "sudh"}
# key = 4
# value = 'sudh
d
# Out:
# {4: 'sudh'}

# %%
d1 = {"key1" : 3334, "key2" : [4,8,3,], "key3" : "nik"}
d1
# Out:
# {'key1': 3334, 'key2': [4, 8, 3], 'key3': 'nik'}

# %%
d1['key1']
# Out:
# 3334

# %%
d1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f64ff61913e8> in <cell line: 1>()
# ----> 1 d1[0]
#
# KeyError: 0

# %%
d = {1 : 'verta',
     2 : 'emir',
     3 : "lanka",
     4 : 'elder',
     5 : 'ardeen'}
d
# Out:
# {1: 'verta', 2: 'emir', 3: 'lanka', 4: 'elder', 5: 'ardeen'}

# %%
d[5]
# Out:
# 'ardeen'

# %%
d[3]
# Out:
# 'lanka'

# %%
d3 = {'+++' : 'vnu'}

# %%
d = {'name': 'nikee', 'mobile' : 54321234 , 'mail' : 'nsk352@vnsf', 'key1' : [5,3,2], 'key2' : (2,3,4,5), 'key3' : {6,5,4,3,3,5,4,7,7}}

# %%
d
# Out:
# {'name': 'nikee',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7}}

# %%
d['key3']
# Out:
# {3, 4, 5, 6, 7}

# %%
d['key1'][0]
# Out:
# 5

# %%
# list of all the keys

d.keys()
# Out:
# dict_keys(['name', 'mobile', 'mail', 'key1', 'key2', 'key3'])

# %%
# list f all values

d.values()
# Out:
# dict_values(['nikee', 54321234, 'nsk352@vnsf', [5, 3, 2], (2, 3, 4, 5), {3, 4, 5, 6, 7}])

# %%
d.items()
# list of keys and value tuple of all
# Out:
# dict_items([('name', 'nikee'), ('mobile', 54321234), ('mail', 'nsk352@vnsf'), ('key1', [5, 3, 2]), ('key2', (2, 3, 4, 5)), ('key3', {3, 4, 5, 6, 7})])

# %%
type(d)
# Out:
# dict

# %%
type(d.items())
# Out:
# dict_items

# %%
d
# Out:
# {'name': 'nikee',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7}}

# %%
d['key4'] = 'new'
d
# Out:
# {'name': 'nikee',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7},
#  'key4': 'new'}

# %%
d['key0'] = 'tasha'
d
# Out:
# {'name': 'nikee',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7},
#  'key4': 'new',
#  'key0': 'tasha'}

# %%
d[5] = 'hgtredf'
d
# Out:
# {'name': 'nikee',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7},
#  'key4': 'new',
#  'key0': 'tasha',
#  5: 'hgtredf'}

# %%
d['name'] = 'SANJAY'

# %%
d
# Out:
# {'name': 'SANJAY',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7},
#  'key4': 'new',
#  'key0': 'tasha',
#  5: 'hgtredf'}

# %%
del d['key0']
d
# delete key0
# Out:
# {'name': 'SANJAY',
#  'mobile': 54321234,
#  'mail': 'nsk352@vnsf',
#  'key1': [5, 3, 2],
#  'key2': (2, 3, 4, 5),
#  'key3': {3, 4, 5, 6, 7},
#  'key4': 'new',
#  5: 'hgtredf'}

# %%
del d
# delete the entire dictionary

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-e983f374794d> in <cell line: 1>()
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
d1 = {'key1' : 'suudh', 'key2' : [2,3,4,5]}

# %%
# list as key will not work
d1[[1,2,3]] = 'ineuron'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-99104083e853> in <cell line: 2>()
#       1 # list as key will not work
# ----> 2 d1[[1,2,3]] = 'ineuron'
#
# TypeError: unhashable type: 'list'

# %%
# tple as key will work
d1[(1,2,4)] = 'ineuron'
d1
# this is coz key is supposed to be a immutable element
# Out:
# {'key1': 'suudh', 'key2': [2, 3, 4, 5], (1, 2, 4): 'ineuron'}

# %%
d1.get('rrr')
# get gets the values of the key we mention if the key is not avilable do nothing

# %%
d1.get('key1')
# Out:
# 'suudh'

# %%
d1 = { 'key1' : "ineuron" , "key" : "FSDS"}
d2 = { 'key2' : 344 , 'key4' : [2,3,5,51]}

# %%
d1.update(d2)
# combines d1 with d2

# %%
d1
# Out:
# {'key1': 'ineuron', 'key': 'FSDS', 'key2': 344, 'key4': [2, 3, 5, 51]}

# %%
d2
# Out:
# {'key2': 344, 'key4': [2, 3, 5, 51]}

# %%
d1 + d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-5fdc4b12eb03> in <cell line: 1>()
# ----> 1 d1 + d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
# fromkey

# %%
key = ('name',"no","mail")
value = ('ikee')

# %%
d7 = dict()

# %%
d = d7.fromkeys(key,value)
d
# Out:
# {'name': 'ikee', 'no': 'ikee', 'mail': 'ikee'}
